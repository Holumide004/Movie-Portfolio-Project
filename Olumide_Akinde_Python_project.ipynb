# %%
#import libraries
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import numpy as np

# %%
#read in the data
df = pd.read_csv('movies 2.csv')

# %%
# Now let's take a look at the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#To check for missing values
for col in df.columns:
  pct_missing = np.mean(df[col].isnull())
  print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
 # To check for data types
 df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change data type of columns
df['budget'] = df['budget'].astype('float64')
df['gross'] = df['gross'].astype('float64')

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#create another year column
df['correctyear'] = df['released'].str.extract(r'(\d{4})')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#to sort the gross revenue in descending order
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                                released  score      votes       director  \
# ...

# %%
#drop duplicates
df['company'].drop_duplicates()
# Out:
# 0              Warner Bros.
# 1         Columbia Pictures
# 2                 Lucasfilm
# 3        Paramount Pictures
# 4            Orion Pictures
#                ...
# 7658           Notis Studio
# 7660    Abominable Pictures
# 7661         Dow Jazz Films
# 7665       Embi Productions
# 7667            PK 65 Films
# Name: company, Length: 2386, dtype: object

# %%
#to check for correlation bewteen budget and gross
#with scatter plot visual
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross')
plt.xlabel('Gross')
plt.ylabel('Budget')

plt.show()

# %%
#using seaborn to plot budget vs gross correlation
sns.regplot(x='budget' , y='gross', data=df, line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#looking at correlation
numeric_df = df.select_dtypes(include=['int64', 'float64'])
numeric_df
#to compute correlation using either spearman rank,pearman,kendall
correlation = numeric_df.corr(method='pearson')
print(correlation)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %% [markdown]
# 0.740395(high +ve) correlation between budget and gross

# %%
#visualize correlation with heatmap
correlation = numeric_df.corr(method='pearson')
sns.heatmap(correlation, annot=True)

plt.title('Correlation Matric for numeric Feature')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#look at company
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_numerized = df

for col_name in df_numerized.columns:
  if(df_numerized[col_name].dtype == 'object'):
      df_numerized[col_name] = df_numerized[col_name].astype('category')
      df_numerized[col_name] = df_numerized[col_name].cat.codes

  df_numerized

# %%
df_numerized.head(5)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  correctyear
# 0  1047       54  19000000.0   46998772.0     2319    146.0            0
# 1   327       55   4500000.0   58853106.0      731    104.0            0
# 2  1745       55  18000000.0  538375067.0     1540    124.0            0
# 3  2246       55   3500000.0   83453539.0     1812     88.0            0
# 4   410       55   6000000.0   39846344.0     1777     98.0            0

# %%
df.head(5)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  correctyear
# 0  1047       54  19000000.0   46998772.0     2319    146.0            0
# 1   327       55   4500000.0   58853106.0      731    104.0            0
# 2  1745       55  18000000.0  538375067.0     1540    124.0            0
# 3  2246       55   3500000.0   83453539.0     1812     88.0            0
# 4   410       55   6000000.0   39846344.0     1777     98.0            0

# %%
# Make a copy of the original data
df_numerized = df.copy()

# Convert text columns to numbers
for col in df_numerized.columns:
    if df_numerized[col].dtype == 'object':
        df_numerized[col] = df_numerized[col].astype('category').cat.codes

# Create correlation matrix
correlation = df_numerized.corr()

# Make the heatmap
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)

# Add labels
plt.title('Correlation Between All Features')
plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#                               ...
# correctyear  budget         0.321918
#              gross          0.250514
#              company       -0.014144
#              runtime        0.120636
#              correctyear    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre        budget        -0.356564
# budget       genre         -0.356564
# gross        genre         -0.235650
# genre        gross         -0.235650
# rating       budget        -0.176002
#                               ...
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# correctyear  correctyear    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# gross        votes          0.630757
# votes        gross          0.630757
# gross        budget         0.740395
# budget       gross          0.740395
# year         correctyear    0.996397
# correctyear  year           0.996397
# director     director       1.000000
# votes        votes          1.000000
# released     released       1.000000
# score        score          1.000000
# rating       rating         1.000000
# name         name           1.000000
# genre        genre          1.000000
# year         year           1.000000
# budget       budget         1.000000
# country      country        1.000000
# writer       writer         1.000000
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# correctyear  correctyear    1.000000
# dtype: float64

# %% [markdown]
# This is a high correlation between budget and gross 0.740395(high +ve) we can infer that the hiher the budget, the likely higher our gross revenue.
#
# The analysis also show a positive correlation bewteen votes and gross revenue (0.63)
